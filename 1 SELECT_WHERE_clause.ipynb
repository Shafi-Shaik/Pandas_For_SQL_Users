# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data Source : https://github.com/pandas-dev/pandas/blob/main/doc/data/titanic.csv

# %%
titanic=pd.read_csv("S:\\Datasets\\titanic.csv")

# %%
titanic.columns=titanic.columns.str.lower()

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ##  Just a basic SELECT clause

# %% [markdown]
# `SLECT * FROM titanic
# `

# %%
titanic
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##  SELECT & LIMIT clause

# %% [markdown]
# `
# SELECT * FROM exercise.titanic LIMIT 3;
# `

# %%
titanic.head(3) # or titanic.tail(3)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ##  SELECT & LIMIT - OFFSET clause

# %% [markdown]
# `
# SELECT * FROM exercise.titanic LIMIT 9,3;
# `

# %%
titanic.iloc[9:12]
# Out:
#     passengerid  survived  pclass                                 name  \
# 9            10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3      Sandstrom, Miss. Marguerite Rut
# 11           12         1       1             Bonnell, Miss. Elizabeth
#
#        sex   age  sibsp  parch   ticket     fare cabin embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 11  female  58.0      0      0   113783  26.5500  C103        S

# %% [markdown]
# ##  SELECT some columns LIMIT clause

# %% [markdown]
# `SELECT passengerid,name,age,sex FROM exercise.titanic LIMIT 3;
# `

# %%
required_cols =['passengerid','name','age','sex']
titanic[required_cols].head(3)
# Out:
#    passengerid                                               name   age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
#
#       sex
# 0    male
# 1  female
# 2  female

# %% [markdown]
# ##  Arithmetic operation with in SELECT  Clause

# %% [markdown]
# `
# SELECT passengerid,name,age*20,sex FROM exercise.titanic LIMIT 3;
# `

# %%
required_cols =['passengerid','name','age','sex']
df=titanic[required_cols].head(3)
df['age']=df['age']*20
df
# Out:
#    passengerid                                               name    age  \
# 0            1                            Braund, Mr. Owen Harris  440.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  760.0
# 2            3                             Heikkinen, Miss. Laina  520.0
#
#       sex
# 0    male
# 1  female
# 2  female

# %% [markdown]
# ##  SELECT with WHERE clause

# %% [markdown]
# ```
# SELECT *
# FROM exercise.titanic
# WHERE passengerid =2
# ```

# %%
titanic[titanic['passengerid']==2] # or titanic.loc[titanic['passengerid']==2]
# Out:
#    passengerid  survived  pclass  \
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch    ticket     fare cabin embarked
# 1      0  PC 17599  71.2833   C85        C

# %% [markdown]
# ```
# SELECT passengerid,name,sex
# FROM exercise.titanic
# WHERE passengerid =2
# ```

# %%
titanic.loc[titanic['passengerid']==2,['passengerid','name','sex']]
# Out:
#    passengerid                                               name     sex
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %% [markdown]
# ##  SELECT - WHERE - IN clauses

# %% [markdown]
# ```
# SELECT passengerid,name,sex
# FROM exercise.titanic
# WHERE passengerid in (2 ,35,78)
# ```

# %%
titanic.loc[titanic['passengerid'].isin([2,35,78]),['passengerid','name','sex']]
# Out:
#     passengerid                                               name     sex
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 34           35                            Meyer, Mr. Edgar Joseph    male
# 77           78                           Moutal, Mr. Rahamin Haim    male

# %% [markdown]
# ##  SELECT - WHERE - OR clauses

# %% [markdown]
# ```
# SELECT passengerid,name,sex
# FROM exercise.titanic
# WHERE passengerid =2
# 	OR  sex ='male'
# ```

# %%
titanic.loc[(titanic['passengerid'].isin([2])) | (titanic['sex']=='female'),['passengerid','name','sex']]
# Out:
#      passengerid                                               name     sex
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)  female
# ..           ...                                                ...     ...
# 880          881       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 882          883                       Dahlberg, Miss. Gerda Ulrika  female
# 885          886               Rice, Mrs. William (Margaret Norton)  female
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
#
# [314 rows x 3 columns]

# %% [markdown]
# ##  SELECT - WHERE - AND clauses

# %% [markdown]
# ```
# SELECT passengerid,name,sex
# FROM exercise.titanic
# WHERE passengerid in (2,35,67)
# 	 AND sex ='female'
# ```

# %%
titanic.loc[(titanic['passengerid'].isin([2,35,67])) & (titanic['sex']=='female'),['passengerid','name','sex']]
# Out:
#     passengerid                                               name     sex
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 66           67                       Nye, Mrs. (Elizabeth Ramell)  female

# %% [markdown]
# ##  SELECT - WHERE - BETWEEN clauses

# %% [markdown]
# ```
# SELECT passengerid,name,age
# FROM exercise.titanic
# WHERE passengerid in (2,35,67)
# 	 AND age between 20 and 29
# ```

# %%
titanic.loc[(titanic['passengerid'].isin([2,35,67])) & (titanic['age'].between(20,29)),['passengerid','name','age']]
# Out:
#     passengerid                          name   age
# 34           35       Meyer, Mr. Edgar Joseph  28.0
# 66           67  Nye, Mrs. (Elizabeth Ramell)  29.0

# %% [markdown]
# ##  SELECT - WHERE - NULL clauses

# %% [markdown]
# ```
# SELECT passengerid,name,age
# FROM exercise.titanic
# WHERE age is  null
# ```

# %%
titanic.loc[titanic['age'].isnull(),['passengerid','name','age']]
# Out:
#      passengerid                                      name  age
# 5              6                          Moran, Mr. James  NaN
# 17            18              Williams, Mr. Charles Eugene  NaN
# 19            20                   Masselmani, Mrs. Fatima  NaN
# 26            27                   Emir, Mr. Farred Chehab  NaN
# 28            29             O'Dwyer, Miss. Ellen "Nellie"  NaN
# ..           ...                                       ...  ...
# 859          860                          Razi, Mr. Raihed  NaN
# 863          864         Sage, Miss. Dorothy Edith "Dolly"  NaN
# 868          869               van Melkebeke, Mr. Philemon  NaN
# 878          879                        Laleff, Mr. Kristo  NaN
# 888          889  Johnston, Miss. Catherine Helen "Carrie"  NaN
#
# [177 rows x 3 columns]

# %% [markdown]
# ##  SELECT - WHERE - NOT NULL clauses

# %% [markdown]
# ```
# SELECT passengerid,name,age
# FROM exercise.titanic
# WHERE age is not null
# ```

# %%
titanic.loc[~titanic['age'].isnull(),['passengerid','name','age']]
# Out:
#      passengerid                                               name   age
# 0              1                            Braund, Mr. Owen Harris  22.0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2              3                             Heikkinen, Miss. Laina  26.0
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4              5                           Allen, Mr. William Henry  35.0
# ..           ...                                                ...   ...
# 885          886               Rice, Mrs. William (Margaret Norton)  39.0
# 886          887                              Montvila, Rev. Juozas  27.0
# 887          888                       Graham, Miss. Margaret Edith  19.0
# 889          890                              Behr, Mr. Karl Howell  26.0
# 890          891                                Dooley, Mr. Patrick  32.0
#
# [714 rows x 3 columns]

# %% [markdown]
# ##  SELECT - WHERE - LIKE clauses

# %% [markdown]
# ```
# SELECT passengerid,name,age
# FROM exercise.titanic
# WHERE name like '%sha%'
# ```

# %%
titanic.loc[titanic['name'].str.contains('sha|Sha',regex=True, na=True),['passengerid','name','age']]
# Out:
#      passengerid                                               name   age
# 177          178                         Isham, Miss. Ann Elizabeth  50.0
# 405          406                                 Gale, Mr. Shadrach  34.0
# 427          428  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  19.0
# 551          552                        Sharp, Mr. Percival James R  27.0
# 705          706     Morley, Mr. Henry Samuel ("Mr Henry Marshall")  39.0
# 798          799                       Ibrahim Shawah, Mr. Yousseff  30.0

# %% [markdown]
# ```
# SELECT passengerid,name,age
# FROM exercise.titanic
# WHERE name like 'sha%'
# ```

# %%
titanic.loc[titanic['name'].str.lower().str.startswith('sha'),['passengerid','name','age']]
# Out:
#      passengerid                         name   age
# 551          552  Sharp, Mr. Percival James R  27.0

# %% [markdown]
# ```
# SELECT passengerid,name,age
# FROM exercise.titanic
# WHERE name like '%sh'
# ```

# %%
titanic.loc[titanic['name'].str.lower().str.endswith('sh'),['passengerid','name','age']]
# Out:
#      passengerid                           name  age
# 633          634  Parr, Mr. William Henry Marsh  NaN

# %% [markdown]
#  ##### Author: &lt; Shafi Mohiddin Shaik&gt; <hr> LinkedIn : [Click to get redirected to Shafi's Linkedin Page]( https://www.linkedin.com/in/shafi-shaik-0279651b0/)
